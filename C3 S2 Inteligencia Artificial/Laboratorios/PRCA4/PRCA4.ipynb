# %%
# !pip install scipy
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scipy in e:\entorno de pruebas\prca3\venv\lib\site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in e:\entorno de pruebas\prca3\venv\lib\site-packages (from scipy) (2.2.4)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in e:\entorno de pruebas\prca3\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\entorno de pruebas\prca3\venv\lib\site-packages (from scikit-learn) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in e:\entorno de pruebas\prca3\venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in e:\entorno de pruebas\prca3\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\entorno de pruebas\prca3\venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## 1: Obtener el dataset

# %%
# Obtener dataset del csv
CSV= pd.read_csv('PCA_datos.csv')
X_or = CSV['0']
Y_or = CSV['Complains']
Y_or.shape
# Out:
# (2836,)

# %% [markdown]
# ## 2: dividir en conjuntos de entrenamiento y test

# %%
x_train, x_test, y_train, y_true = train_test_split(X_or,Y_or, test_size=0.3)

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
# y_train = pd.DataFrame(y_train)
# y_true = pd.DataFrame(y_true)

# %%
print("el tamaño de x es {}, el tamaño de y es {}".format(x_train.shape, y_train.shape))
print("el tamaño de x_test es {}, el tamaño de y_true es {}".format(x_test.shape, y_true.shape))
# Out:
# el tamaño de x es (1985, 1), el tamaño de y es (1985,)
# el tamaño de x_test es (851, 1), el tamaño de y_true es (851,)

# %% [markdown]
# # KNN

# %% [markdown]
# ## 3: Entrenar y ejecutar el modelo

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(x_test)

# %% [markdown]
# ## 4: Evaluar el modelo

# %%
confusion_matrix(y_true, y_pred_knn)
# Out:
# array([[775,  12],
#        [ 61,   3]])

# %%
puntuacion_knn_antigua = accuracy_score(y_true, y_pred_knn)
print(puntuacion_knn_antigua)
# Out:
# 0.9142185663924794

# %%
puntuacion_knn_balanceada_antigua =balanced_accuracy_score(y_true, y_pred_knn)
print(puntuacion_knn_balanceada_antigua)
# Out:
# 0.5158136118170267

# %% [markdown]
# En este caso, es mejor usar la puntuación balanceada, ya que hay muchos más valores de 0 (sin quejas) que de 1.
# Esto lleva al KNN a confundirse y tener muchos falsos negativos a la hora de detectar quejas como se ve en la matriz de confusión.

# %% [markdown]
# ## 5: Optimizar K

# %%
clf = GridSearchCV(KNeighborsClassifier(),scoring='balanced_accuracy',param_grid={'n_neighbors':[2,3,4,5,6,7,8,15,16,31,32]})

clf.fit(pd.DataFrame(X_or),Y_or)
df_resultados_grid = pd.DataFrame(clf.cv_results_)
df_resultados_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003039      0.000911         0.030230        0.005386
# 1        0.002424      0.000416         0.027580        0.002940
# 2        0.003174      0.000646         0.028301        0.002071
# 3        0.002441      0.000285         0.027537        0.003872
# 4        0.001984      0.000126         0.022167        0.001171
# 5        0.002032      0.000133         0.021032        0.000257
# 6        0.002255      0.000283         0.021945        0.000983
# 7        0.002065      0.000139         0.022687        0.000979
# 8        0.001950      0.000085         0.021411        0.000220
# 9        0.002061      0.000231         0.021787        0.000239
# 10       0.001940      0.000075         0.022257        0.001062
#
#     param_n_neighbors               params  split0_test_score  \
# 0                   2   {'n_neighbors': 2}           0.504165
# 1                   3   {'n_neighbors': 3}           0.497460
# 2                   4   {'n_neighbors': 4}           0.505122
# 3                   5   {'n_neighbors': 5}           0.513118
# 4                   6   {'n_neighbors': 6}           0.509912
# 5                   7   {'n_neighbors': 7}           0.509912
# 6                   8   {'n_neighbors': 8}           0.500000
# 7                  15  {'n_neighbors': 15}           0.500000
# 8                  16  {'n_neighbors': 16}           0.500000
# 9                  31  {'n_neighbors': 31}           0.500000
# 10                 32  {'n_neighbors': 32}           0.500000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.499040           0.501273           0.489443
# 1            0.516941           0.502545           0.511495
# 2            0.500000           0.492322           0.500313
# 3            0.498081           0.499353           0.507344
# 4            0.499040           0.495202           0.495202
# 5            0.498081           0.492322           0.491363
# 6            0.500000           0.499040           0.499040
# 7            0.500000           0.500000           0.500000
# 8            0.500000           0.500000           0.500000
# 9            0.500000           0.500000           0.500000
# 10           0.500000           0.500000           0.500000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.506071         0.499998        0.005800                8
# 1            0.503192         0.506327        0.006959                1
# 2            0.509910         0.501534        0.005861                3
# 3            0.509910         0.505561        0.005894                2
# 4            0.500000         0.499871        0.005388                9
# 5            0.500000         0.498336        0.006658               11
# 6            0.500000         0.499616        0.000470               10
# 7            0.500000         0.500000        0.000000                4
# 8            0.500000         0.500000        0.000000                4
# 9            0.500000         0.500000        0.000000                4
# 10           0.500000         0.500000        0.000000                4

# %%
clf.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Con estos resultados, queda probado que el mejor estimador entre los posibles k escogidos es k=3

# %% [markdown]
# ## 6: Reentrenar KNN con el k seleccionado

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
y_pred_knn = knn.predict(x_test)

# %%
confusion_matrix(y_true, y_pred_knn)
# Out:
# array([[769,  18],
#        [ 60,   4]])

# %%
puntuacion_knn_nueva = accuracy_score(y_true, y_pred_knn)

# %%
puntuacion_knn_balanceada_nueva = balanced_accuracy_score(y_true, y_pred_knn)

# %%
print('La puntuación sin balancear ha pasado de {0} a {1}'.format(puntuacion_knn_antigua, puntuacion_knn_nueva))
print('La puntuación balanceada ha pasado de {0} a {1}'.format(puntuacion_knn_balanceada_antigua, puntuacion_knn_balanceada_nueva))
# Out:
# La puntuación sin balancear ha pasado de 0.9142185663924794 a 0.9083431257344301
# La puntuación balanceada ha pasado de 0.5158136118170267 a 0.51981416772554

# %% [markdown]
# Como estábamos priorizando la puntuación balanceada, al haber mejora en esta, podemos decir que el modelo ha mejorado.

# %% [markdown]
# # Árboles de decisión

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## 3: Entrenar y ejecutar el modelo

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_arbol = clf.predict(x_test)

# %% [markdown]
# ## 4: Evaluar el modelo

# %%
confusion_matrix(y_true, y_pred_arbol)
# Out:
# array([[725,  62],
#        [ 51,  13]])

# %%
puntuacion_arbol_antigua = accuracy_score(y_true, y_pred_arbol)
print(puntuacion_arbol_antigua)
# Out:
# 0.8672150411280846

# %%
puntuacion_arbol_balanceada_antigua = balanced_accuracy_score(y_true, y_pred_arbol)
print(puntuacion_arbol_balanceada_antigua)
# Out:
# 0.5621724110546379

# %% [markdown]
# Estamos ante el mismo caso del KNN

# %% [markdown]
# ## 5: Optimizar el árbol

# %%
clf = GridSearchCV(DecisionTreeClassifier(),scoring='balanced_accuracy',param_grid={'max_depth':[2,3,4,5,6,7,8,9,10,15,30,90,270]})

# %%
clf.fit(pd.DataFrame(X_or),Y_or)
df_resultados_grid = pd.DataFrame(clf.cv_results_)
df_resultados_grid
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006106      0.000594         0.004986        0.000634
# 1        0.004908      0.001439         0.003421        0.000995
# 2        0.004157      0.000451         0.002835        0.000838
# 3        0.006128      0.000994         0.003348        0.000846
# 4        0.004434      0.000111         0.002463        0.000106
# 5        0.004271      0.000297         0.002145        0.000189
# 6        0.005124      0.000346         0.002763        0.000654
# 7        0.004686      0.000269         0.002077        0.000091
# 8        0.004628      0.000100         0.001978        0.000091
# 9        0.004826      0.000206         0.001992        0.000264
# 10       0.005007      0.000089         0.001937        0.000232
# 11       0.006433      0.000295         0.002788        0.000405
# 12       0.006698      0.000275         0.002699        0.000346
#
#     param_max_depth              params  split0_test_score  split1_test_score  \
# 0                 2    {'max_depth': 2}           0.500000           0.500000
# 1                 3    {'max_depth': 3}           0.498084           0.498081
# 2                 4    {'max_depth': 4}           0.498084           0.497121
# 3                 5    {'max_depth': 5}           0.498084           0.497121
# 4                 6    {'max_depth': 6}           0.498084           0.503192
# 5                 7    {'max_depth': 7}           0.507038           0.503192
# 6                 8    {'max_depth': 8}           0.505122           0.499353
# 7                 9    {'max_depth': 9}           0.502249           0.494555
# 8                10   {'max_depth': 10}           0.500333           0.494555
# 9                15   {'max_depth': 15}           0.520490           0.488797
# 10               30   {'max_depth': 30}           0.505164           0.497100
# 11               90   {'max_depth': 90}           0.505164           0.494221
# 12              270  {'max_depth': 270}           0.505164           0.494221
#
#     split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 0            0.500000           0.510870           0.498081         0.501790
# 1            0.500000           0.500000           0.498081         0.498849
# 2            0.507990           0.498081           0.498081         0.499871
# 3            0.507990           0.499040           0.498081         0.500063
# 4            0.507031           0.499040           0.494242         0.500318
# 5            0.504152           0.493282           0.492322         0.499997
# 6            0.504152           0.490403           0.492322         0.498271
# 7            0.500313           0.484645           0.491363         0.494625
# 8            0.498394           0.481766           0.489443         0.492898
# 9            0.494868           0.466411           0.502545         0.494622
# 10           0.516920           0.470562           0.541538         0.506257
# 11           0.516920           0.469603           0.541538         0.505489
# 12           0.516920           0.469603           0.541538         0.505489
#
#     std_test_score  rank_test_score
# 0         0.004600                4
# 1         0.000940                9
# 2         0.004077                8
# 3         0.004010                6
# 4         0.004401                5
# 5         0.006017                7
# 6         0.006000               10
# 7         0.006336               11
# 8         0.006695               13
# 9         0.017674               12
# 10        0.023313                1
# 11        0.023854                2
# 12        0.023854                2

# %%
clf.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=30)

# %% [markdown]
# ## 6: Reentrenar el árbol con el max_depth seleccionado

# %%
clf = DecisionTreeClassifier(max_depth=30)
clf.fit(x_train, y_train)
y_pred_arbol = clf.predict(x_test)

# %%
confusion_matrix(y_true, y_pred_arbol)
# Out:
# array([[725,  62],
#        [ 51,  13]])

# %%
puntuacion_arbol_nueva = accuracy_score(y_true, y_pred_arbol)

# %%
puntuacion_arbol_balanceada_nueva = balanced_accuracy_score(y_true, y_pred_arbol)

# %%
print('La puntuación sin balancear ha pasado de {0} a {1}'.format(puntuacion_arbol_antigua, puntuacion_arbol_nueva))
print('La puntuación balanceada ha pasado de {0} a {1}'.format(puntuacion_arbol_balanceada_antigua, puntuacion_arbol_balanceada_nueva))
# Out:
# La puntuación sin balancear ha pasado de 0.8672150411280846 a 0.8672150411280846
# La puntuación balanceada ha pasado de 0.5621724110546379 a 0.5621724110546379

# %% [markdown]
# # Comparación de resultados

# %%
print('La puntuación sin balancear del KNN ha pasado de {0} a {1}'.format(puntuacion_knn_antigua, puntuacion_knn_nueva))
print('La puntuación balanceada del KNN ha pasado de {0} a {1}'.format(puntuacion_knn_balanceada_antigua, puntuacion_knn_balanceada_nueva))
print('La puntuación sin balancear del árbol ha pasado de {0} a {1}'.format(puntuacion_arbol_antigua, puntuacion_arbol_nueva))
print('La puntuación balanceada del árbol ha pasado de {0} a {1}'.format(puntuacion_arbol_balanceada_antigua, puntuacion_arbol_balanceada_nueva))
# Out:
# La puntuación sin balancear del KNN ha pasado de 0.9142185663924794 a 0.9083431257344301
# La puntuación balanceada del KNN ha pasado de 0.5158136118170267 a 0.51981416772554
# La puntuación sin balancear del árbol ha pasado de 0.8672150411280846 a 0.8672150411280846
# La puntuación balanceada del árbol ha pasado de 0.5621724110546379 a 0.5621724110546379

# %% [markdown]
# En este caso el KNN ha tenido una mejora de resultados más pronunciada y tuvo los mejores resultados
