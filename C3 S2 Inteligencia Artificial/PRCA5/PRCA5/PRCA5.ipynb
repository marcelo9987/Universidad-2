# %%
import datetime
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: seaborn in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\oficial\universidad-2\c3 s2 inteligencia artificial\prca5\prca5\venv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

# %%
# Cargar datos
train = pd.read_csv("train.csv")
print(train.head())
# Out:
#    id   Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0  346.0       12.5      0.25     0.25     0.75   0.63              69.7
# 1   1  707.0       25.0      0.50     0.38     0.50   0.50              69.7
# 2   2   42.0       12.5      0.25     0.25     0.25   0.25              86.0
# 3   3  532.0       25.0      0.50     0.25     0.50   0.75              69.7
# 4   4  380.0       12.5      0.25     0.38     0.38   0.75              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              42.1                  58.2              50.2              24.3
# 1              42.1                  58.2              50.2              24.3
# 2              52.0                  71.9              62.0              30.0
# 3              42.1                  58.2              50.2              24.3
# 4              52.0                  71.9              62.0              30.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# 0                  41.2         16.0                0.26  0.579982   0.466183
# 1                  41.2         34.0                0.56  0.476202   0.413904
# 2                  50.8         34.0                0.56  0.442693   0.427277
# 3                  41.2         34.0                0.56  0.389453   0.381768
# 4                  50.8         24.0                0.39  0.633463   0.517160
#
#        seeds       yield
# 0  39.288162  7660.88604
# 1  34.744180  5946.05226
# 2  34.159346  4867.94772
# 3  29.833158  4042.84264
# 4  44.278583  8254.12654

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15000 non-null  int64
#  1   Row#                  15000 non-null  float64
#  2   clonesize             15000 non-null  float64
#  3   honeybee              15000 non-null  float64
#  4   bumbles               15000 non-null  float64
#  5   andrena               15000 non-null  float64
#  6   osmia                 15000 non-null  float64
#  7   MaxOfUpperTRange      15000 non-null  float64
#  8   MinOfUpperTRange      15000 non-null  float64
#  9   AverageOfUpperTRange  15000 non-null  float64
#  10  MaxOfLowerTRange      15000 non-null  float64
#  11  MinOfLowerTRange      15000 non-null  float64
#  12  AverageOfLowerTRange  15000 non-null  float64
#  13  RainingDays           15000 non-null  float64
#  14  AverageRainingDays    15000 non-null  float64
#  15  fruitset              15000 non-null  float64
#  16  fruitmass             15000 non-null  float64
#  17  seeds                 15000 non-null  float64
#  18  yield                 15000 non-null  float64
# dtypes: float64(18), int64(1)
# memory usage: 2.2 MB

# %%
train.describe()
# Out:
#                  id          Row#     clonesize      honeybee       bumbles  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean    7499.500000    427.661000     19.813000      0.386948      0.283968
# std     4330.271354    213.281489      6.657739      0.333622      0.058612
# min        0.000000      0.000000     10.000000      0.000000      0.000000
# 25%     3749.750000    247.000000     12.500000      0.250000      0.250000
# 50%     7499.500000    468.000000     25.000000      0.500000      0.250000
# 75%    11249.250000    597.000000     25.000000      0.500000      0.380000
# max    14999.000000    776.000000     37.500000     18.430000      0.585000
#
#             andrena         osmia  MaxOfUpperTRange  MinOfUpperTRange  \
# count  15000.000000  15000.000000      15000.000000      15000.000000
# mean       0.487883      0.592445         82.247747         49.716600
# std        0.149041      0.145625          9.101710          5.519546
# min        0.000000      0.000000         69.700000         39.000000
# 25%        0.380000      0.500000         77.400000         46.800000
# 50%        0.500000      0.630000         86.000000         52.000000
# 75%        0.630000      0.750000         86.000000         52.000000
# max        0.750000      0.750000         94.600000         57.200000
#
#        AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# count          15000.000000      15000.000000      15000.000000
# mean              68.716073         59.282347         28.686787
# std                7.602871          6.580402          3.179193
# min               55.900000         33.000000         24.300000
# 25%               64.700000         55.800000         27.000000
# 50%               71.900000         62.000000         30.000000
# 75%               71.900000         62.000000         30.000000
# max               79.000000         68.200000         33.000000
#
#        AverageOfLowerTRange   RainingDays  AverageRainingDays      fruitset  \
# count          15000.000000  15000.000000        15000.000000  15000.000000
# mean              48.612267     18.872669            0.328190      0.499957
# std                5.363480     11.864746            0.166879      0.076711
# min               41.200000      1.000000            0.020000      0.192732
# 25%               45.800000     16.000000            0.260000      0.451104
# 50%               50.800000     16.000000            0.260000      0.505120
# 75%               50.800000     24.000000            0.390000      0.559628
# max               55.900000     34.000000            0.560000      0.836961
#
#           fruitmass         seeds         yield
# count  15000.000000  15000.000000  15000.000000
# mean       0.445531     36.064502   6009.294311
# std        0.038130      4.080522   1356.655150
# min        0.192732     22.079199   1637.704020
# 25%        0.417947     33.228900   5126.993180
# 50%        0.446451     36.018624   6107.382470
# 75%        0.471665     39.046593   7019.694380
# max        0.836961     47.803070   8969.401840

# %%
train.tail()
# Out:
#           id   Row#  clonesize  honeybee  bumbles  andrena  osmia  \
# 14995  14995  572.0       25.0      0.50     0.25     0.50   0.63
# 14996  14996  734.0       25.0      0.50     0.38     0.50   0.63
# 14997  14997  736.0       25.0      0.50     0.38     0.50   0.75
# 14998  14998  301.0       12.5      0.25     0.25     0.63   0.75
# 14999  14999  306.0       12.5      0.25     0.25     0.63   0.75
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# 14995              86.0              52.0                  71.9
# 14996              77.4              46.8                  64.7
# 14997              86.0              52.0                  71.9
# 14998              94.6              57.2                  79.0
# 14999              86.0              52.0                  71.9
#
#        MaxOfLowerTRange  MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 14995              62.0              30.0                  50.8         16.0
# 14996              55.8              27.0                  45.8         34.0
# 14997              62.0              30.0                  50.8         16.0
# 14998              68.2              33.0                  55.9          1.0
# 14999              62.0              30.0                  50.8         24.0
#
#        AverageRainingDays  fruitset  fruitmass      seeds       yield
# 14995                0.26  0.525063   0.462462  37.033298  6493.47253
# 14996                0.56  0.384646   0.395636  29.742583  3826.17226
# 14997                0.26  0.462752   0.437923  34.702412  5367.61826
# 14998                0.10  0.517723   0.460369  37.379452  6328.89332
# 14999                0.39  0.447041   0.424609  33.743494  4936.36477

# %% [markdown]
# ## Buscar nulos y duplicados

# %%
train.isnull().sum()
# Out:
# id                      0
# Row#                    0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # EDA (Exploratory data analysis)

# %%
train.describe()
# Out:
#                  id          Row#     clonesize      honeybee       bumbles  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean    7499.500000    427.661000     19.813000      0.386948      0.283968
# std     4330.271354    213.281489      6.657739      0.333622      0.058612
# min        0.000000      0.000000     10.000000      0.000000      0.000000
# 25%     3749.750000    247.000000     12.500000      0.250000      0.250000
# 50%     7499.500000    468.000000     25.000000      0.500000      0.250000
# 75%    11249.250000    597.000000     25.000000      0.500000      0.380000
# max    14999.000000    776.000000     37.500000     18.430000      0.585000
#
#             andrena         osmia  MaxOfUpperTRange  MinOfUpperTRange  \
# count  15000.000000  15000.000000      15000.000000      15000.000000
# mean       0.487883      0.592445         82.247747         49.716600
# std        0.149041      0.145625          9.101710          5.519546
# min        0.000000      0.000000         69.700000         39.000000
# 25%        0.380000      0.500000         77.400000         46.800000
# 50%        0.500000      0.630000         86.000000         52.000000
# 75%        0.630000      0.750000         86.000000         52.000000
# max        0.750000      0.750000         94.600000         57.200000
#
#        AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# count          15000.000000      15000.000000      15000.000000
# mean              68.716073         59.282347         28.686787
# std                7.602871          6.580402          3.179193
# min               55.900000         33.000000         24.300000
# 25%               64.700000         55.800000         27.000000
# 50%               71.900000         62.000000         30.000000
# 75%               71.900000         62.000000         30.000000
# max               79.000000         68.200000         33.000000
#
#        AverageOfLowerTRange   RainingDays  AverageRainingDays      fruitset  \
# count          15000.000000  15000.000000        15000.000000  15000.000000
# mean              48.612267     18.872669            0.328190      0.499957
# std                5.363480     11.864746            0.166879      0.076711
# min               41.200000      1.000000            0.020000      0.192732
# 25%               45.800000     16.000000            0.260000      0.451104
# 50%               50.800000     16.000000            0.260000      0.505120
# 75%               50.800000     24.000000            0.390000      0.559628
# max               55.900000     34.000000            0.560000      0.836961
#
#           fruitmass         seeds         yield
# count  15000.000000  15000.000000  15000.000000
# mean       0.445531     36.064502   6009.294311
# std        0.038130      4.080522   1356.655150
# min        0.192732     22.079199   1637.704020
# 25%        0.417947     33.228900   5126.993180
# 50%        0.446451     36.018624   6107.382470
# 75%        0.471665     39.046593   7019.694380
# max        0.836961     47.803070   8969.401840

# %% [markdown]
# ## Univariante

# %% [markdown]
# ### Row

# %%
plt.boxplot('Row#', data=train)
plt.title('Boxplot de Row#')
plt.xlabel('Row#')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# Como esta variable no parece tener mucha utilidad, la eliminamos.

# %%
train = train.drop(columns=['Row#'])

# %% [markdown]
# ### Histograma de todas las variables

# %%
train.hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.suptitle('Histogramas de las variables numéricas')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# sacamos los diagramas respecto a yield
sns.pairplot(train, y_vars='yield')

# %%
plt.boxplot(train['yield'])
plt.title('Boxplot de Yield')
plt.show()

# %%
plt.boxplot(train['honeybee'])
plt.title('Boxplot de Honeybees')
plt.show()

# %%
plt.boxplot(train['bumbles'])
plt.title('Boxplot de Temperature')
plt.show()

# %% [markdown]
# # Transformaciones

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No hay duplicados, por lo que no es necesario eliminarlos.

# %% [markdown]
# Elimino la variable que quiero predecir, que es yield.

# %%
X = train.drop(columns=["id",'yield'])
Y = train['yield']

# %% [markdown]
# Procedo a normalizar los datos, ya que las variables tienen diferentes escalas.

# %%
scaler = MinMaxScaler()

pd_normalizado = scaler.fit_transform(X)

# %% [markdown]
# Ahora, hago PCA

# %%
modelo = PCA(n_components=12)
modelo.fit_transform(pd_normalizado)
# Out:
# array([[-1.09445403e+00, -2.62690738e-01, -3.17745565e-01, ...,
#         -6.02297511e-03, -8.84321793e-03,  6.08133188e-04],
#        [-1.11486072e+00,  6.20431335e-01,  6.20034896e-02, ...,
#         -1.96488172e-02, -1.34788957e-02,  6.30604220e-07],
#        [ 3.15495130e-01,  6.41851388e-01, -1.93688834e-01, ...,
#          2.00591112e-03,  2.88070953e-03, -1.64356542e-04],
#        ...,
#        [ 3.30048468e-01, -1.05725166e-01,  1.81593474e-01, ...,
#          7.96418103e-03,  7.70251466e-03, -7.08901419e-04],
#        [ 1.09553022e+00, -6.98579035e-01, -1.50717530e-01, ...,
#          1.41198269e-03, -7.21362761e-04,  1.91155551e-04],
#        [ 3.22479802e-01,  1.69789375e-01, -2.92403436e-01, ...,
#          4.33833910e-03,  9.72974147e-04, -9.70424875e-04]],
#       shape=(15000, 12))

# %%
plt.plot(modelo.explained_variance_ratio_.cumsum())
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %% [markdown]
# Escogeremos 5 componentes principales, ya que sobre con 5 componentes explicamos el 95% de la varianza.

# %%
modelo = PCA(n_components=5)
pd_pca=pd.DataFrame(modelo.fit_transform(pd_normalizado))

# %%
df_pca = pd.concat([pd_pca, train['yield']], axis=1)

# %%
df_pca
# Out:
#               0         1         2         3         4       yield
# 0     -1.094454 -0.262691 -0.317746  0.198157  0.225069  7660.88604
# 1     -1.114861  0.620431  0.062003  0.020417 -0.037827  5946.05226
# 2      0.315495  0.641851 -0.193689 -0.576209  0.108669  4867.94772
# 3     -1.119293  0.664338  0.078403  0.200199 -0.081716  4042.84264
# 4      0.334225  0.044956 -0.453316  0.002891 -0.344281  8254.12654
# ...         ...       ...       ...       ...       ...         ...
# 14995  0.333048 -0.126100  0.161295  0.101371 -0.049557  6493.47253
# 14996 -0.440849  0.686821  0.119528  0.105207 -0.047587  3826.17226
# 14997  0.330048 -0.105725  0.181593  0.193125 -0.151994  5367.61826
# 14998  1.095530 -0.698579 -0.150718  0.150615  0.125306  6328.89332
# 14999  0.322480  0.169789 -0.292403  0.174263  0.116172  4936.36477
#
# [15000 rows x 6 columns]

# %% [markdown]
# # Análisis de regresión

# %%
# Importamos el dataset de prueba
test = pd.read_csv("test.csv")
X_test = test.drop(columns=["id","Row#"])
# Normalizamos el dataset de prueba usando el mismo scaler
test_escalado = pd.DataFrame(scaler.transform(X_test))
# Aplicamos la transformación PCA usando el mismo modelo
test_pca = pd.DataFrame(modelo.transform(test_escalado))

# %%
modelo_reg = LinearRegression()
# Entrenamos el modelo de regresión lineal con los datos de entrenamiento
modelo_reg.fit(pd_pca, Y)
predicciones = modelo_reg.predict(test_pca)

# %%
# Ponemos el id (primera columna del dataset de test) en el DataFrame de predicciones
predicciones = pd.DataFrame({
    "id": test["id"],
    "yield": predicciones
})

# %%
# Guardamos las predicciones en un archivo CSV
predicciones.to_csv('predicciones/predicciones_'+datetime.datetime.now().strftime("%Y%m%d_%H%M%S")+'.csv'
                    , index=False)
